# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import torch
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
from sklearn.preprocessing import LabelEncoder 
from sklearn.metrics import accuracy_score, log_loss,roc_auc_score

# %%
train = pd.read_csv('/content/drive/MyDrive/sevilla hackathon/Data/train.csv')
test = pd.read_csv('/content/drive/MyDrive/sevilla hackathon/Data/test.csv')
features=train.drop(['rating_num'], axis=1)
label=train['rating_num']
features.head(5)
# Out:
#    row_id  scout_id  winner   team  competitionId  player_position_1  \
# 0       1        13  winner  team1              8                7.0
# 1       3        16   loser  team2              8                3.0
# 2       4         4   loser  team1              5               11.0
# 3       5        13   loser  team2              4               17.0
# 4       7        11    draw  team1              5               10.0
#
#    player_position_2  player_height  player_weight  player_general_var_0  ...  \
# 0                7.0       0.317073           0.48                   0.0  ...
# 1                9.0       0.463415           0.42                   0.0  ...
# 2               11.0       0.682927           0.44                   0.0  ...
# 3               17.0       0.682927           0.58                   0.0  ...
# 4               10.0       0.731707           0.70                   0.0  ...
#
#    team2_defensive_derived_var_10  team2_offensive_derived_var_11  \
# 0                        0.193658                        0.131548
# 1                        0.190500                        0.173697
# 2                        0.312314                        0.250756
# 3                        0.282556                        0.155969
# 4                        0.450453                        0.199050
#
#    team2_offensive_derived_var_12  team2_offensive_derived_var_13  \
# 0                        0.097131                        0.600944
# 1                        0.272801                        0.605659
# 2                        0.212631                        0.558833
# 3                        0.206503                        0.533002
# 4                        0.134002                        0.688773
#
#    team2_offensive_derived_var_14  team2_defensive_derived_var_15  \
# 0                        0.338892                        0.347980
# 1                        0.526761                        0.468976
# 2                        0.686523                        0.441749
# 3                        0.373959                        0.527733
# 4                        0.681724                        0.733625
#
#    team2_offensive_derived_var_16  team2_defensive_derived_var_17  \
# 0                        0.034157                        0.288962
# 1                        0.054034                        0.334962
# 2                        0.219441                        0.414288
# 3                        0.095201                        0.423040
# 4                        0.128719                        0.448360
#
#    team2_offensive_derived_var_18  team2_offensive_derived_var_19
# 0                        0.310727                        0.204925
# 1                        0.380073                        0.295392
# 2                        0.570757                        0.437500
# 3                        0.330754                        0.235558
# 4                        0.444946                        0.312500
#
# [5 rows x 799 columns]

# %% [markdown]
# #Encoding

# %%
def binary_encode(df, column, positive_value):
    df = df.copy()
    df[column] = df[column].apply(lambda x: 1 if x == positive_value else 0)
    return df

# %%
def three_encode(df, column, a_value,b_value):
    df = df.copy()
    df[column] = df[column].apply(lambda x: 2 if x == a_value else (1 if x == b_value
                                  else 0))
    return df

# %%
features= three_encode(features, 'winner', 'winner','draw')
features=binary_encode(features, "team","team1")
features.head(5)
# Out:
#    row_id  scout_id  winner  team  competitionId  player_position_1  \
# 0       1        13       2     1              8                7.0
# 1       3        16       0     0              8                3.0
# 2       4         4       0     1              5               11.0
# 3       5        13       0     0              4               17.0
# 4       7        11       1     1              5               10.0
#
#    player_position_2  player_height  player_weight  player_general_var_0  ...  \
# 0                7.0       0.317073           0.48                   0.0  ...
# 1                9.0       0.463415           0.42                   0.0  ...
# 2               11.0       0.682927           0.44                   0.0  ...
# 3               17.0       0.682927           0.58                   0.0  ...
# 4               10.0       0.731707           0.70                   0.0  ...
#
#    team2_defensive_derived_var_10  team2_offensive_derived_var_11  \
# 0                        0.193658                        0.131548
# 1                        0.190500                        0.173697
# 2                        0.312314                        0.250756
# 3                        0.282556                        0.155969
# 4                        0.450453                        0.199050
#
#    team2_offensive_derived_var_12  team2_offensive_derived_var_13  \
# 0                        0.097131                        0.600944
# 1                        0.272801                        0.605659
# 2                        0.212631                        0.558833
# 3                        0.206503                        0.533002
# 4                        0.134002                        0.688773
#
#    team2_offensive_derived_var_14  team2_defensive_derived_var_15  \
# 0                        0.338892                        0.347980
# 1                        0.526761                        0.468976
# 2                        0.686523                        0.441749
# 3                        0.373959                        0.527733
# 4                        0.681724                        0.733625
#
#    team2_offensive_derived_var_16  team2_defensive_derived_var_17  \
# 0                        0.034157                        0.288962
# 1                        0.054034                        0.334962
# 2                        0.219441                        0.414288
# 3                        0.095201                        0.423040
# 4                        0.128719                        0.448360
#
#    team2_offensive_derived_var_18  team2_offensive_derived_var_19
# 0                        0.310727                        0.204925
# 1                        0.380073                        0.295392
# 2                        0.570757                        0.437500
# 3                        0.330754                        0.235558
# 4                        0.444946                        0.312500
#
# [5 rows x 799 columns]

# %%
test= three_encode(test, 'winner', 'winner','draw')
test=binary_encode(test, "team","team1")
test.head(5)
# Out:
#    row_id  scout_id  winner  team  competitionId  player_position_1  \
# 0   14785        16       1     1            7.0                4.0
# 1   15125         2       1     1            9.0               11.0
# 2   13095        16       0     0           10.0               19.0
# 3    6079        16       0     1           11.0                3.0
# 4   16584        11       2     1            5.0                4.0
#
#    player_position_2  player_height  player_weight  player_general_var_0  ...  \
# 0                4.0       0.317073           0.44                   0.0  ...
# 1               11.0       0.560976           0.60                   0.0  ...
# 2               19.0       0.195122           0.30                   0.0  ...
# 3                9.0       0.341463           0.30                   0.0  ...
# 4                4.0       0.585366           0.70                   0.2  ...
#
#    team2_defensive_derived_var_10  team2_offensive_derived_var_11  \
# 0                        0.268842                        0.190509
# 1                        0.346640                        0.198072
# 2                        0.351175                        0.177065
# 3                        0.496021                        0.313902
# 4                        0.396398                        0.191068
#
#    team2_offensive_derived_var_12  team2_offensive_derived_var_13  \
# 0                        0.311739                        0.628642
# 1                        0.246104                        0.536949
# 2                        0.262470                        0.650741
# 3                        0.405065                        0.490855
# 4                        0.042083                        0.838704
#
#    team2_offensive_derived_var_14  team2_defensive_derived_var_15  \
# 0                        0.405323                        0.309039
# 1                        0.486006                        0.487637
# 2                        0.567063                        0.486774
# 3                        0.591251                        0.608131
# 4                        0.689723                        0.522480
#
#    team2_offensive_derived_var_16  team2_defensive_derived_var_17  \
# 0                        0.114849                        0.454992
# 1                        0.105279                        0.501402
# 2                        0.062118                        0.251021
# 3                        0.294538                        0.322264
# 4                        0.090986                        0.437002
#
#    team2_offensive_derived_var_18  team2_offensive_derived_var_19
# 0                        0.304133                        0.328816
# 1                        0.381214                        0.499620
# 2                        0.586227                        0.267774
# 3                        0.685016                        0.293783
# 4                        0.476399                        0.437500
#
# [5 rows x 799 columns]

# %% [markdown]
# #!! Start

# %%
def rmissingvaluecol(dff,threshold):
    l = []
    l = list(dff.drop(dff.loc[:,list((100*(dff.isnull().sum()/len(dff.index))>=threshold))].columns, 1).columns.values)
    print("# Columns having more than %s percent missing values:"%threshold,(dff.shape[1] - len(l)))
    print("Columns:\n",list(set(list((dff.columns.values))) - set(l)))
    return l

l=rmissingvaluecol(features,80)
df = features[l]
# Out:
# # Columns having more than 80 percent missing values: 51
# Columns:
#  ['team2_other_ratio_var_32', 'team1_other_raw_var_31', 'team1_other_raw_var_33', 'player_other_ratio_var_36', 'player_other_ratio_var_28', 'player_offensive_ratio_var_70', 'player_other_ratio_var_14', 'team1_other_raw_var_43', 'team1_other_ratio_var_33', 'team1_other_ratio_var_32', 'player_other_ratio_var_26', 'team1_other_raw_var_50', 'player_offensive_ratio_var_68', 'team2_other_raw_var_40', 'player_other_ratio_var_32', 'player_other_ratio_var_37', 'team2_other_raw_var_92', 'team2_other_raw_var_43', 'player_defensive_ratio_var_39', 'team2_other_raw_var_51', 'player_positional_ratio_var_79', 'team2_other_raw_var_19', 'team1_other_raw_var_19', 'team1_other_raw_var_82', 'player_defensive_ratio_var_16', 'player_other_ratio_var_25', 'team2_other_raw_var_72', 'team2_other_raw_var_33', 'team2_other_raw_var_50', 'player_other_ratio_var_27', 'team1_other_raw_var_51', 'player_other_ratio_var_23', 'player_other_ratio_var_67', 'player_offensive_ratio_var_77', 'team1_other_raw_var_38', 'player_offensive_ratio_var_72', 'team1_other_raw_var_92', 'player_other_ratio_var_73', 'player_other_ratio_var_24', 'team2_other_raw_var_31', 'player_offensive_ratio_var_69', 'team2_other_raw_var_82', 'player_other_ratio_var_34', 'team1_other_raw_var_72', 'team2_other_ratio_var_33', 'player_positional_ratio_var_22', 'team1_other_raw_var_40', 'player_offensive_ratio_var_78', 'team2_other_raw_var_38', 'player_defensive_ratio_var_38', 'player_other_ratio_var_33']
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
def missing(dff):
    print (round((dff.isnull().sum() * 100/ len(dff)),2).sort_values(ascending=False))
missing(df)
# Out:
# player_offensive_ratio_var_13    79.61
# player_other_ratio_var_66        74.45
# player_offensive_ratio_var_40    74.21
# player_offensive_ratio_var_19    61.60
# player_offensive_ratio_var_57    60.99
#                                  ...
# player_general_var_2              0.00
# player_general_var_3              0.00
# player_general_var_5              0.00
# scout_id                          0.00
# row_id                            0.00
# Length: 748, dtype: float64

# %%
df.apply(lambda x: x.fillna(x.median(),inplace=True))
# Out:
# row_id                            None
# scout_id                          None
# winner                            None
# team                              None
# competitionId                     None
#                                   ...
# team2_defensive_derived_var_15    None
# team2_offensive_derived_var_16    None
# team2_defensive_derived_var_17    None
# team2_offensive_derived_var_18    None
# team2_offensive_derived_var_19    None
# Length: 748, dtype: object

# %% [markdown]
# #!! STOP

# %%
#Check for  null values
df.isnull().sum()
# Out:
# row_id                            0
# scout_id                          0
# winner                            0
# team                              0
# competitionId                     0
#                                  ..
# team2_defensive_derived_var_15    0
# team2_offensive_derived_var_16    0
# team2_defensive_derived_var_17    0
# team2_offensive_derived_var_18    0
# team2_offensive_derived_var_19    0
# Length: 748, dtype: int64

# %%
test=test[l]
test.shape
# Out:
# (8774, 748)

# %%
#df= train.to_numpy()
# split data into input and output columns
#X, y = df[:, :-1], df[:, -1]

# %%
# creating testing and training datasets
#spliting the data in to test and train sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df, label, test_size = 0.3)
y_train = np.ravel(y_train)
y_test = np.ravel(y_test)

# %% [markdown]
# #!!

# %%
# !pip uninstall scikit-learn -y

# !pip install -U scikit-learn

# %% [markdown]
# #!!

# %% [markdown]
# # Feature Selection

# %% [markdown]
# Selecting all features

# %%
from sklearn.feature_selection import SelectKBest, chi2,f_regression
# configure to select all features
fs = SelectKBest(score_func=f_regression, k='all')
# learn relationship from training data
fs.fit(X_train, y_train)
# transform train input data
X_train_fs = fs.transform(X_train)
# transform test input data
X_test_fs = fs.transform(X_test)
#print(X_train_fs, X_test_fs, fs)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_univariate_selection.py:289: RuntimeWarning: invalid value encountered in true_divide
#   correlation_coefficient /= X_norms

# %%
# what are scores for the features
for i in range(len(fs.scores_)):
	print('Feature %d: %f' % (i, fs.scores_[i]))
# plot the scores
from matplotlib import pyplot
pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_)
pyplot.show()

# %% [markdown]
# Selecting using mutual information

# %%
from sklearn.feature_selection import SelectKBest, chi2,mutual_info_regression
...
# feature selection
def select_features(X_train, y_train, X_test):
	# configure to select all features
	fs = SelectKBest(score_func=mutual_info_regression, k='all')
	# learn relationship from training data
	fs.fit(X_train, y_train)
	# transform train input data
	X_train_fs = fs.transform(X_train)
	# transform test input data
	X_test_fs = fs.transform(X_test)
	return X_train_fs, X_test_fs, fs

# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)
# what are scores for the features
for i in range(len(fs.scores_)):
	print('Feature %d: %f' % (i, fs.scores_[i]))
# plot the scores
pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_)
pyplot.show()

# %% [markdown]
# #Modelling

# %%
#Model using all features
import xgboost
from xgboost import XGBRegressor
# create an xgboost regression model
model_0 = XGBRegressor(n_estimators=40, max_depth=5)#, eta=0.1, subsample=0.7, colsample_bytree=0.8)
# define model evaluation method
from sklearn.model_selection import RepeatedKFold
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

# %%
# feature selection function
def select_features(X_train, y_train, X_test):
	# configure to select a subset of features
	fs = SelectKBest(score_func=f_regression, k=100)
	# learn relationship from training data
	fs.fit(X_train, y_train)
	# transform train input data
	X_train_fs = fs.transform(X_train)
	# transform test input data
	X_test_fs = fs.transform(X_test)
	return X_train_fs, X_test_fs, fs

# %%
#Model using above selected functions
from xgboost import XGBRegressor
# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)
# fit the model
model_1 = XGBRegressor(n_estimators=40, max_depth=5)
model_1.fit(X_train_fs, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_univariate_selection.py:289: RuntimeWarning: invalid value encountered in true_divide
#   correlation_coefficient /= X_norms
# [14:07:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(max_depth=5, n_estimators=40)

# %%
import pickle
model_1.fit(df, label)
pickle.dump(model, open("model.pickle.dat", "wb"))
# Out:
# [14:10:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
yhat = model_1.predict(X_test)
yhat
# Out:
# array([7.2548237, 5.865543 , 7.0873733, ..., 6.8361044, 7.8148866,
#        6.384784 ], dtype=float32)

# %%
 from sklearn.metrics import r2_score
 r2_score(y_test, yhat)
# Out:
# 0.3250639259274324

# %%
y_pred = model_1.predict(test[l])
y_pred
# Out:
# array([7.136431 , 6.145101 , 6.3353944, ..., 6.318975 , 6.208568 ,
#        7.481691 ], dtype=float32)

# %%
result = pd.DataFrame(y_pred,columns=['rating_num'], )
result['row_id']=test['row_id']
result=result[['row_id','rating_num']]
result
# Out:
#       row_id  rating_num
# 0      14785    7.136431
# 1      15125    6.145101
# 2      13095    6.335394
# 3       6079    6.414126
# 4      16584    7.046569
# ...      ...         ...
# 8769   21259    5.964577
# 8770    9371    7.948693
# 8771   23226    6.318975
# 8772   26623    6.208568
# 8773   13814    7.481691
#
# [8774 rows x 2 columns]

# %%
def round_nearest(x, a):
    return round(x / a) * a

# %%
result['rating_num']=round_nearest(result['rating_num'],0.5)

# %%
result
# Out:
#       row_id  rating_num
# 0      14785         7.0
# 1      15125         6.0
# 2      13095         6.5
# 3       6079         6.5
# 4      16584         7.0
# ...      ...         ...
# 8769   21259         6.0
# 8770    9371         8.0
# 8771   23226         6.5
# 8772   26623         6.0
# 8773   13814         7.5
#
# [8774 rows x 2 columns]

# %%
result.to_csv('/content/drive/MyDrive/sevilla hackathon/AB/solution4.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-96f450dd6b4d> in <module>()
# ----> 1 result.to_csv('/content/drive/MyDrive/sevilla hackathon/AH/solution1.csv',index=False)
#
# NameError: name 'result' is not defined
